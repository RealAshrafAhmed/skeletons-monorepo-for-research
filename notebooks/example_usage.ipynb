# %% [markdown]
# # Example: Using Monorepo Packages
#
# This notebook demonstrates how to use packages from the monorepo.

# %%
# Load the jupyter ai extension
# %load_ext jupyter_ai
# Out:
# The jupyter_ai extension is already loaded. To reload it, use:
#   %reload_ext jupyter_ai

# %%
# %ai list
# Out:
# ai21
# Requires environment variable: AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# gpt4all
# * gpt4all:ggml-gpt4all-j-v1.2-jazzy
# * gpt4all:ggml-gpt4all-j-v1.3-groovy
# * gpt4all:ggml-gpt4all-l13b-snoozy
# * gpt4all:mistral-7b-openorca.Q4_0
# * gpt4all:mistral-7b-instruct-v0.1.Q4_0
# * gpt4all:gpt4all-falcon-q4_0
# * gpt4all:wizardlm-13b-v1.2.Q4_0
# * gpt4all:nous-hermes-llama2-13b.Q4_0
# * gpt4all:gpt4all-13b-snoozy-q4_0
# * gpt4all:mpt-7b-chat-merges-q4_0
# * gpt4all:orca-mini-3b-gguf2-q4_0
# * gpt4all:starcoder-q4_0
# * gpt4all:rift-coder-v0-7b-q4_0
# * gpt4all:em_german_mistral_v01.Q4_0
#
# huggingface_hub
# Requires environment variable: HUGGINGFACEHUB_API_TOKEN (not set)
# ...

# %%
# %%ai gpt2
# draw 10 samples from a standard normal distribution and plot sample histogram
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 get_ipython().run_cell_magic('ai', 'gpt2', 'draw 10 samples from a standard normal distribution and plot sample histogram\n')
#
# File ~/skeletons-monorepo-for-research/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
#    2575 # when using magics with decorator @output_can_be_silenced
#    2576 # when the last Python token in the expression is a ';'.
#    2577 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %ai list
# Out:
# ai21
# Requires environment variable: AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# gpt4all
# * gpt4all:ggml-gpt4all-j-v1.2-jazzy
# * gpt4all:ggml-gpt4all-j-v1.3-groovy
# * gpt4all:ggml-gpt4all-l13b-snoozy
# * gpt4all:mistral-7b-openorca.Q4_0
# * gpt4all:mistral-7b-instruct-v0.1.Q4_0
# * gpt4all:gpt4all-falcon-q4_0
# * gpt4all:wizardlm-13b-v1.2.Q4_0
# * gpt4all:nous-hermes-llama2-13b.Q4_0
# * gpt4all:gpt4all-13b-snoozy-q4_0
# * gpt4all:mpt-7b-chat-merges-q4_0
# * gpt4all:orca-mini-3b-gguf2-q4_0
# * gpt4all:starcoder-q4_0
# * gpt4all:rift-coder-v0-7b-q4_0
# * gpt4all:em_german_mistral_v01.Q4_0
#
# huggingface_hub
# Requires environment variable: HUGGINGFACEHUB_API_TOKEN (not set)
# ...

# %%
#
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Import from your local packages
# from pymc_extensions import column_stack_vars

sns.set_theme()

# %% [markdown]
# ## Example Analysis
#
# Replace this with your actual analysis.

# %%
# Example plot
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.title("Example Plot")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.show()

# %% [markdown]
# ## Next Steps
#
# - Add your own analysis code
# - Use functions from your packages
# - Document your experiments

# %%
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('ai', '', 'a program that asks me for my name\n')
#
# File ~/skeletons-monorepo-for-research/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
#    2575 # when using magics with decorator @output_can_be_silenced
#    2576 # when the last Python token in the expression is a ';'.
#    2577 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/skeletons-monorepo-for-research/.venv/lib/python3.12/site-packages/jupyter_ai_magics/magics.py:628, in AiMagics.ai(self, line, cell)
# ...
